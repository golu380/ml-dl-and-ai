# %%
import numpy as np

import matplotlib.pyplot as plt 
from scipy import stats

# %%
pagespeed = np.random.normal(3.0,1.0,1000);

# %%
purchaseAmount = 100- (pagespeed-np.random.normal(1.0,0.1,1000))*3

# %%
plt.scatter(pagespeed,purchaseAmount)

# %%
slope,intercept,r_value,p_value,std_err = stats.linregress(pagespeed,purchaseAmount)

# %%
slope
# Out:
# -2.985490807102658

# %%
intercept
# Out:
# 102.97134716003853

# %%
r_value
# Out:
# -0.9947586759879123

# %%
p_value
# Out:
# 0.0

# %%
std_err
# Out:
# 0.00971400711754151

# %%
def predict(x):
    return slope*x + intercept

fitline = predict(pagespeed)
plt.scatter(pagespeed,purchaseAmount)
plt.plot(pagespeed,fitline, c='r')
plt.show()
